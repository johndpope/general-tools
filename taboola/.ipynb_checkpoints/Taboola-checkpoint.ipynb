# %%
import numpy as np
import pandas as pd 
import scipy
import glob
import os
import random 
import math

import keras
from keras.models import Sequential
from keras.layers import *
from keras.regularizers import *
from keras.wrappers.scikit_learn import KerasClassifier
from keras.preprocessing.image import ImageDataGenerator
import keras.backend as K
import tensorflow as tf
print("tensorflow - {}".format(tf.__version__))

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from sklearn.feature_extraction import image
import sklearn.preprocessing 
import sklearn.model_selection
import seaborn as sns 

# %matplotlib inline
# Out:
# tensorflow - 0.11.0rc2

# %%
# %run '../general/datasets.py'

# %%
# %run '../general/dl.py'

# %%
# %run '../general/plotting.py'

# %% [raw]
# ## Load VGG model

# %% [markdown]
# # Load training set
# ## Extract patches from images

# %%
import pickle
import bz2
import gzip
import time

with bz2.BZ2File("data/dataset.pickle.bz2", 'r') as f:
    data = pickle.load(f)

# %%
DATA_PATH = "data"
N_PATCHES_PER_IMAGE = 4
PATCH_SIZE = (100, 100)


def extract_patches(directory):
    Xs = []
    ys = []
    
    for label_dir in glob.glob("{}/*".format(directory)):
        label = os.path.basename(label_dir)
        
        for filename in glob.glob("{}/*".format(label_dir)):
            img = scipy.misc.imread(filename, mode='RGB')
            if (img.shape[0]<PATCH_SIZE[0] or img.shape[1]<PATCH_SIZE[1]): continue
            
            t = image.extract_patches_2d(img, PATCH_SIZE, max_patches=N_PATCHES_PER_IMAGE)
            Xs.append(t)
            ys.append([label]*t.shape[0])

    return np.concatenate(Xs), np.concatenate(ys)
            
            
Xs, ys = extract_patches(DATA_PATH)
Xs = Xs.astype(float) / 255.0

# %% [markdown]
# # Encode labels as OneHot vectors

# %%
l_enc = sklearn.preprocessing.LabelEncoder()
oh_enc = sklearn.preprocessing.OneHotEncoder()

def encode_ys(ys):
    ysl = l_enc.fit_transform(ys).reshape(-1,1)
    return oh_enc.fit_transform(ysl).toarray()

def decode_ys(yse):
    l = np.argmax(yse, axis=1)
    return l_enc.inverse_transform(l)
     
yse = encode_ys(ys)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-128a8f436ddc> in <module>()
#      10     return l_enc.inverse_transform(l)
#      11
# ---> 12 yse = encode_ys(ys)
#
# NameError: name 'ys' is not defined

# %% [markdown]
# ## Build datasets

# %%
data = Datasets(Xs, yse, test_split=0.4, train_dev_split=0.1, dev_split=0.5, small=500)

# %%
data.show()
# Out:
# train
#   - X: (1323, 100, 100, 3)
#   - y: (1323, 2)
# train_dev
#   - X: (148, 100, 100, 3)
#   - y: (148, 2)
# dev
#   - X: (491, 100, 100, 3)
#   - y: (491, 2)
# test
#   - X: (490, 100, 100, 3)
#   - y: (490, 2)
# small
# train
#   - X: (500, 100, 100, 3)
#   - y: (500, 2)
# test
#   - X: (500, 100, 100, 3)
#   - y: (500, 2)

# %%
import pickle
import bz2
import gzip
import time

with bz2.BZ2File("data/dataset.pickle.bz2", 'w') as f:
    pickle.dump(data, f)

# %% [markdown]
# # calc mean/std of images

# %%
X_train_means = data.train.X.mean(axis=0)
X_train_std = data.train.X.std(axis=(0,1,2))

# %%
# Out:
# array([ 0.28205813,  0.27570862,  0.30276995])

# %%
sample_idx = np.random.choice(np.arange(data.train.X.shape[0]), 18, replace=False)
gridplot(data.train.X[sample_idx], titles=data.train.y[sample_idx])

# %% [markdown]
# # Build ConvNet

# %%
H,W,DIMS = 100, 100, 3

def build_detector_model(opt='adam', num_filters=(64,64,64,32,32), batchnorm=True):
    model = Sequential()

    # Adding CONV0 layers
    model.add(ZeroPadding2D(padding=(2, 2), input_shape=(H,W,DIMS)))
    model.add(Convolution2D(num_filters[0],5,5, name='conv0_0', activation='relu'))
    model.add(ZeroPadding2D(padding=(2, 2)))
    model.add(Convolution2D(num_filters[1],5,5, name='conv0_1', activation='relu'))
    model.add(ZeroPadding2D(padding=(2, 2)))
    model.add(Convolution2D(num_filters[2],5,5, name='conv0_2', activation='relu'))
    model.add(ZeroPadding2D(padding=(2, 2)))
    model.add(Convolution2D(num_filters[3],5,5, name='conv0_3', activation='relu'))
    model.add(ZeroPadding2D(padding=(2, 2)))
    model.add(Convolution2D(num_filters[4],5,5, name='conv0_4', activation='linear'))
    if batchnorm:
        model.add(BatchNormalization(name='bn_conv0', momentum=0.9, mode=0, axis=-1))
    model.add(Activation('relu'))
        

    # Adding MAXPOOLING 
    ll = model.layers[-1].output_shape[1:3]
    model.add(MaxPooling2D(ll, name='maxpooling_conv0'))

    # FC to outputs
    model.add(Flatten())
    model.add(Dense(2, name='output', activation='linear'))
    model.add(Activation('softmax'))
    
    # Compile model
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
def build_model(num_filters=(16,32), fc_size=(32,), reg=True, reg_lambda=0.01):
    model = Sequential()
    
    def additional_args():
        return { 'input_shape': Xs_conv.shape[1:] } if len(model.layers) == 0 else {}
    
    reg_params = dict(W_regularizer=l2(reg_lambda), b_regularizer=l2(reg_lambda))
    
    
    for n in num_filters:
        model.add(Convolution2D(n, 3,3, activation='relu', **additional_args()))
        model.add(Convolution2D(n, 3,3, activation='relu'))
        model.add(MaxPooling2D(pool_size=(2,2)))
        if reg: 
            model.add(Dropout(0.5))

    #model.add(MaxPooling2D(pool_size=model.layers[-1].output_shape[1:3]))

    
    model.add(Flatten())
    
    for n in fc_size:
        model.add(Dense(n, activation='relu', **reg_params))
    
    model.add(Dense(2, activation='softmax'))
    
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model = build_detector_model(batchnorm=True)
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# zeropadding2d_10 (ZeroPadding2D) (None, 104, 104, 3)   0           zeropadding2d_input_1[0][0]
# ____________________________________________________________________________________________________
# conv0_0 (Convolution2D)          (None, 100, 100, 64)  4864        zeropadding2d_10[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_11 (ZeroPadding2D) (None, 104, 104, 64)  0           conv0_0[0][0]
# ____________________________________________________________________________________________________
# conv0_1 (Convolution2D)          (None, 100, 100, 64)  102464      zeropadding2d_11[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_12 (ZeroPadding2D) (None, 104, 104, 64)  0           conv0_1[0][0]
# ____________________________________________________________________________________________________
# conv0_2 (Convolution2D)          (None, 100, 100, 64)  102464      zeropadding2d_12[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_13 (ZeroPadding2D) (None, 104, 104, 64)  0           conv0_2[0][0]
# ____________________________________________________________________________________________________
# conv0_3 (Convolution2D)          (None, 100, 100, 32)  51232       zeropadding2d_13[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_14 (ZeroPadding2D) (None, 104, 104, 32)  0           conv0_3[0][0]
# ____________________________________________________________________________________________________
# conv0_4 (Convolution2D)          (None, 100, 100, 32)  25632       zeropadding2d_14[0][0]
# ____________________________________________________________________________________________________
# bn_conv0 (BatchNormalization)    (None, 100, 100, 32)  64          conv0_4[0][0]
# ____________________________________________________________________________________________________
# activation_21 (Activation)       (None, 100, 100, 32)  0           bn_conv0[0][0]
# ____________________________________________________________________________________________________
# maxpooling_conv0 (MaxPooling2D)  (None, 1, 1, 32)      0           activation_21[0][0]
# ____________________________________________________________________________________________________
# flatten_12 (Flatten)             (None, 32)            0           maxpooling_conv0[0][0]
# ____________________________________________________________________________________________________
# output (Dense)                   (None, 2)             66          flatten_12[0][0]
# ____________________________________________________________________________________________________
# activation_22 (Activation)       (None, 2)             0           output[0][0]
# ====================================================================================================
# Total params: 286786
# ____________________________________________________________________________________________________

# %%
X = (data.train.X - X_train_means) / X_train_std

hist = model.fit(X, data.train.y, nb_epoch=200, verbose=2, validation_split=0.2)
# Out:
# Train on 1058 samples, validate on 265 samples
# Epoch 1/200
# 10s - loss: 0.0707 - acc: 0.9726 - val_loss: 0.0989 - val_acc: 0.9623
# Epoch 91/200
# 10s - loss: 0.0628 - acc: 0.9783 - val_loss: 0.1017 - val_acc: 0.9698
# Epoch 92/200
# 10s - loss: 0.0662 - acc: 0.9745 - val_loss: 0.1088 - val_acc: 0.9660
# Epoch 93/200

# %%
plt.plot(hist.history['acc'], label='acc', c='blue')
plt.plot(hist.history['val_acc'], label='val acc', c='red')
plt.plot(hist.history['loss'], label='loss', c='blue', linestyle='dashed')
plt.plot(hist.history['val_loss'], label='val loss', c='red', linestyle='dashed')
plt.legend(loc='best')

# %%
y_test_pred = np.argmax(model.predict((data.test.X - X_train_means)/X_train_std), axis=1)
(y_test_pred == np.argmax(data.test.y, axis=1)).mean()
# Out:
# 0.93061224489795913

# %%
gridplot(data.test.X[:10], titles=[ "true={}, pred={}".format(t,p) for t,p in zip(np.argmax(data.test.y[:10], axis=1), y_test_pred) ])

# %%
def get_layer_desc(layer):
    if isinstance(layer, keras.layers.Flatten):
        return ""
    elif isinstance(layer, keras.layers.Dense):
        return ""
    elif isinstance(layer, keras.layers.Convolution2D):
        return "{}x({},{})".format(layer.nb_filter, layer.nb_row, layer.nb_col)
    elif isinstance(layer, keras.layers.MaxPooling2D):
        return layer.pool_size
    elif isinstance(layer, keras.layers.normalization.BatchNormalization):
        return "BatchNormalization"
        

def analyze_layer(model, layer_num, trainingset=None, calculate_repr_inputs=True, l2_regularizer=0.01, lr=0.1):
    model_input_shape = model.input_shape[1:]
    layer = model.layers[layer_num]
    layer_name = type(layer).__name__
    print("analyzing layer {}...".format(layer_name))
    
    l_input_shape = layer.input.get_shape()
    l_output_shape = layer.output.get_shape()
    
    res = dict( 
        name=layer_name, 
        desc=get_layer_desc(layer),
        input_shape=l_input_shape,
        output_shape=l_output_shape
    )
    
    w = layer.get_weights()
    if type(layer) in [keras.layers.Dense, keras.layers.Convolution2D]: 
        l_w, l_b = w
        num_elements = l_b.shape[0]
        element_shape = l_w.shape[:len(l_w.shape)-1]

        res['num_learning_elements'] = num_elements
        res['learning_element_shape'] = element_shape
        
        input_img = model.layers[0].input
    
        # Calculating the representative inputs
        repr_inputs = np.zeros((num_elements, ) + model_input_shape)
        if calculate_repr_inputs:
            for element_id in range(num_elements):
                # NOTICE: repr element is neuron (0,0) in the conv act map. this is also used when
                # calculating avg neuron affect on output
                repr_element_id = [0]*(len(l_output_shape)-1) + [element_id]

                input_shape = (1,)+model_input_shape
                curr_input = np.zeros(input_shape)
                curr_input += np.random.random(input_shape) * 0.1

                filter_act = layer.output[repr_element_id] - l2_regularizer*K.sum(input_img)
                grads = K.gradients(filter_act, input_img)[0] 
                grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)
                it = K.function([input_img, K.learning_phase()], [filter_act, grads])

                learning_rate = lr
                num_iters = 100
                if it([curr_input, False])[0] == 0:
                    curr_input = np.random.random(input_shape)

                for i in range(num_iters):
                    curr_act, curr_grads = it([curr_input, False])
                    curr_input += learning_rate * curr_grads
                    learning_rate *= 0.98

                repr_inputs[element_id,:] = curr_input

            res['learning_elements_repr_inputs'] = repr_inputs

        if trainingset is not None:
#             # Calculating average neuron effect on the final output
#             d_output_layer_output_func = K.function([model.layers[0].input, K.learning_phase()], [K.gradients(model.output, layer.output)[0]])
#             d_output_layer_output = d_output_layer_output_func([trainingset, False])[0]
#             res['grads_on_output'] = d_output_layer_output.mean(axis=tuple(range(len(l_output_shape)-1)))

            # Average Activation Map
            act_map = K.function([model.layers[0].input, K.learning_phase()], [layer.output])
            res['activation_map'] = act_map([trainingset, False])[0].mean(axis=0)
            
        
    return res

# %%
def display_analyzed_layer(anl_layer, display_limit=-1):
    print("{} {}".format(anl_layer['name'], anl_layer['desc']))
    print("Input: {}".format(anl_layer['input_shape']))
    print("Output: {}".format(anl_layer['output_shape']))


    if 'num_learning_elements' in anl_layer:

        num_ri = anl_layer['num_learning_elements']

        fig = plt.figure(figsize=(15,15*8/int(math.ceil(num_ri/8))))
        gs = gridspec.GridSpec(int(math.ceil(num_ri/8)), 8, wspace=0.0, hspace=0.05)

        inner_gs = [ gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs[i], wspace=0.0, hspace=0.05) for i in range(num_ri) ]

        for i in range(num_ri):
            if 'learning_elements_repr_inputs' in anl_layer:
                repr_inputs = anl_layer['learning_elements_repr_inputs']
                inp = repr_inputs[i,:].squeeze()
                inp = (inp * X_train_std) + X_train_means
                inp = (inp - inp.min()) / (inp.max() - inp.min())

                img = inp[:display_limit,:display_limit]

                ri_ax = plt.Subplot(fig, inner_gs[i][0])
                ri_ax.set_title("Activating Input #{}".format(i))
                ri_ax.set_xticks([])
                ri_ax.set_yticks([])
                ri_ax.imshow(img, cmap=plt.cm.gray, interpolation='nearest')
                fig.add_subplot(ri_ax)
                
                img = img.mean(axis=2)
                ri_ax = plt.Subplot(fig, inner_gs[i][1])
                ri_ax.set_xticks([])
                ri_ax.set_yticks([])
                ri_ax.imshow(img, cmap=plt.cm.gray, interpolation='nearest')
                fig.add_subplot(ri_ax)
                

                
            if 'activation_map' in anl_layer:
                actmap = np.moveaxis(anl_layer['activation_map'],-1,0)[i]
                if len(actmap.shape) == 0: continue
                
                act_ax = plt.Subplot(fig, inner_gs[i][2])
                act_ax.imshow(actmap, cmap=plt.cm.gray, interpolation='nearest')
                act_ax.set_xticks([])
                act_ax.set_yticks([])
                fig.add_subplot(act_ax)
        plt.show()

# %%
ts = ((data.train.X - X_train_means)/X_train_std)[data.train.y[:,0]==1]
anl_layers = [ analyze_layer(model, l, calculate_repr_inputs=True, trainingset=ts, l2_regularizer=0.001) for l in range(len(model.layers)) ]
# Out:
# analyzing layer ZeroPadding2D...
# analyzing layer Convolution2D...
# analyzing layer ZeroPadding2D...
# analyzing layer Convolution2D...
# analyzing layer ZeroPadding2D...
# analyzing layer Convolution2D...
# analyzing layer ZeroPadding2D...
# analyzing layer Convolution2D...
# analyzing layer ZeroPadding2D...
# analyzing layer Convolution2D...
# analyzing layer BatchNormalization...
# analyzing layer Activation...
# analyzing layer MaxPooling2D...
# analyzing layer Flatten...
# analyzing layer Dense...
# analyzing layer Activation...

# %%
al = analyze_layer(model, 14, calculate_repr_inputs=True, trainingset=ts, l2_regularizer=0.001)
#display_analyzed_layer(anl_layers[-2], display_limit=None)
display_analyzed_layer(al, display_limit=None)
# Out:
# analyzing layer Dense...
# Dense
# Input: (?, ?)
# Output: (?, 2)

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# zeropadding2d_10 (ZeroPadding2D) (None, 104, 104, 3)   0           zeropadding2d_input_1[0][0]
# ____________________________________________________________________________________________________
# conv0_0 (Convolution2D)          (None, 100, 100, 64)  4864        zeropadding2d_10[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_11 (ZeroPadding2D) (None, 104, 104, 64)  0           conv0_0[0][0]
# ____________________________________________________________________________________________________
# conv0_1 (Convolution2D)          (None, 100, 100, 64)  102464      zeropadding2d_11[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_12 (ZeroPadding2D) (None, 104, 104, 64)  0           conv0_1[0][0]
# ____________________________________________________________________________________________________
# conv0_2 (Convolution2D)          (None, 100, 100, 64)  102464      zeropadding2d_12[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_13 (ZeroPadding2D) (None, 104, 104, 64)  0           conv0_2[0][0]
# ____________________________________________________________________________________________________
# conv0_3 (Convolution2D)          (None, 100, 100, 32)  51232       zeropadding2d_13[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_14 (ZeroPadding2D) (None, 104, 104, 32)  0           conv0_3[0][0]
# ____________________________________________________________________________________________________
# conv0_4 (Convolution2D)          (None, 100, 100, 32)  25632       zeropadding2d_14[0][0]
# ____________________________________________________________________________________________________
# bn_conv0 (BatchNormalization)    (None, 100, 100, 32)  64          conv0_4[0][0]
# ____________________________________________________________________________________________________
# activation_21 (Activation)       (None, 100, 100, 32)  0           bn_conv0[0][0]
# ____________________________________________________________________________________________________
# maxpooling_conv0 (MaxPooling2D)  (None, 1, 1, 32)      0           activation_21[0][0]
# ____________________________________________________________________________________________________
# flatten_12 (Flatten)             (None, 32)            0           maxpooling_conv0[0][0]
# ____________________________________________________________________________________________________
# output (Dense)                   (None, 2)             66          flatten_12[0][0]
# ____________________________________________________________________________________________________
# activation_22 (Activation)       (None, 2)             0           output[0][0]
# ====================================================================================================
# Total params: 286786
# ____________________________________________________________________________________________________

# %%
sample_idx = np.random.chiceose(range(data.dev.X.shape[0]), 20)
sample_X = data.dev.X[sample_idx]
sample_y = data.dev.y[sample_idx]

gridplot(sample_X, titles=sample_y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/numpy/core/fromnumeric.py in choose(a, choices, out, mode)
#     346     try:
# --> 347         choose = a.choose
#     348     except AttributeError:
#
# AttributeError: 'range' object has no attribute 'choose'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-157-b30604ef0017> in <module>()
# ----> 1 sample_idx = np.choose(range(data.dev.X.shape[0]), 20)
#       2 sample_X = data.dev.X[sample_idx]
#       3 sample_y = data.dev.y[sample_idx]
#       4
#       5 gridplot(sample_X, titles=sample_y)
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/numpy/core/fromnumeric.py in choose(a, choices, out, mode)
#     347         choose = a.choose
#     348     except AttributeError:
# --> 349         return _wrapit(a, 'choose', choices, out=out, mode=mode)
#     350     return choose(choices, out=out, mode=mode)
#     351
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      45     except AttributeError:
#      46         wrap = None
# ---> 47     result = getattr(asarray(obj), method)(*args, **kwds)
#      48     if wrap:
#      49         if not isinstance(result, mu.ndarray):
#
# TypeError: object of type 'int' has no len()

# %%
results_dropout = compare_models(data.train.X, data.train.y, build_model, {
        '(16,16)_32_Dropout_0.1': { 'num_filters': (16,16), 'fc_size': (32,), 'reg': True, 'reg_lambda': 0.1 },
        '(16,16)_32_Dropout_0.01': { 'num_filters': (16,16), 'fc_size': (32,), 'reg': True, 'reg_lambda': 0.01 },
        '(16,16)_32_Dropout_0.001': { 'num_filters': (16,16), 'fc_size': (32,), 'reg': True, 'reg_lambda': 0.001 },
        '(16,16)_32_Dropout_0.0001': { 'num_filters': (16,16), 'fc_size': (32,), 'reg': True, 'reg_lambda': 0.0001 },
    }, nb_epoch=100)
# Out:
# Train on 1058 samples, validate on 265 samples
# Epoch 1/100
# 6s - loss: 0.7374 - acc: 0.5274 - val_loss: 0.6583 - val_acc: 0.5811
# Epoch 2/100
# 4s - loss: 0.6170 - acc: 0.7240 - val_loss: 0.3931 - val_acc: 0.8491
# Epoch 3/100
# 4s - loss: 0.4180 - acc: 0.8422 - val_loss: 0.3541 - val_acc: 0.8717
# Epoch 4/100
# 4s - loss: 0.3502 - acc: 0.8752 - val_loss: 0.7378 - val_acc: 0.6302
# Epoch 5/100
# 4s - loss: 0.4334 - acc: 0.8355 - val_loss: 0.3432 - val_acc: 0.8943
# Epoch 6/100
# 4s - loss: 0.3113 - acc: 0.8828 - val_loss: 0.7194 - val_acc: 0.6340
# Epoch 7/100
# 4s - loss: 0.3269 - acc: 0.8790 - val_loss: 0.3201 - val_acc: 0.8717
# Epoch 8/100
# 4s - loss: 0.2579 - acc: 0.9112 - val_loss: 0.3324 - val_acc: 0.8604
# Epoch 9/100
# 4s - loss: 0.2406 - acc: 0.9216 - val_loss: 0.3027 - val_acc: 0.8679
# Epoch 10/100
# 4s - loss: 0.2449 - acc: 0.9045 - val_loss: 0.2847 - val_acc: 0.8755
# Epoch 11/100
# 4s - loss: 0.2829 - acc: 0.9055 - val_loss: 0.3524 - val_acc: 0.8679
# Epoch 12/100
# 4s - loss: 0.2156 - acc: 0.9291 - val_loss: 0.2597 - val_acc: 0.8906
# Epoch 13/100
# 4s - loss: 0.2853 - acc: 0.9045 - val_loss: 0.3124 - val_acc: 0.8755
# Epoch 14/100
# 4s - loss: 0.2968 - acc: 0.9074 - val_loss: 0.3056 - val_acc: 0.8981
# Epoch 15/100
# 4s - loss: 0.2452 - acc: 0.9149 - val_loss: 0.2601 - val_acc: 0.8792
# Epoch 16/100
# 4s - loss: 0.2057 - acc: 0.9357 - val_loss: 0.3370 - val_acc: 0.8642
# Epoch 17/100
# 4s - loss: 0.1847 - acc: 0.9461 - val_loss: 0.9702 - val_acc: 0.6151
# Epoch 18/100
# 4s - loss: 0.5558 - acc: 0.7713 - val_loss: 0.4440 - val_acc: 0.8151
# Epoch 19/100
# 4s - loss: 0.3586 - acc: 0.8733 - val_loss: 0.3361 - val_acc: 0.8604
# Epoch 20/100
# 4s - loss: 0.2814 - acc: 0.9083 - val_loss: 0.3717 - val_acc: 0.8415
# Epoch 21/100
# 4s - loss: 0.2149 - acc: 0.9348 - val_loss: 0.2669 - val_acc: 0.8906
# Epoch 22/100
# 4s - loss: 0.1880 - acc: 0.9452 - val_loss: 0.3985 - val_acc: 0.8264
# Epoch 23/100
# 4s - loss: 0.2258 - acc: 0.9178 - val_loss: 0.2565 - val_acc: 0.8943
# Epoch 24/100
# 4s - loss: 0.1729 - acc: 0.9480 - val_loss: 0.2161 - val_acc: 0.9057
# Epoch 25/100
# 4s - loss: 0.1563 - acc: 0.9537 - val_loss: 0.3260 - val_acc: 0.8792
# Epoch 26/100
# 4s - loss: 0.1850 - acc: 0.9490 - val_loss: 0.2855 - val_acc: 0.8943
# Epoch 27/100
# 4s - loss: 0.1435 - acc: 0.9603 - val_loss: 0.3120 - val_acc: 0.8679
# Epoch 28/100
# 4s - loss: 0.1473 - acc: 0.9575 - val_loss: 0.5095 - val_acc: 0.8151
# Epoch 29/100
# 4s - loss: 0.1972 - acc: 0.9405 - val_loss: 0.2447 - val_acc: 0.9019
# Epoch 30/100
# 4s - loss: 0.2992 - acc: 0.9036 - val_loss: 0.2739 - val_acc: 0.8792
# Epoch 31/100
# 4s - loss: 0.1803 - acc: 0.9452 - val_loss: 0.2341 - val_acc: 0.9132
# Epoch 32/100
# 4s - loss: 0.1583 - acc: 0.9556 - val_loss: 0.2793 - val_acc: 0.8830
# Epoch 33/100
# 4s - loss: 0.1464 - acc: 0.9612 - val_loss: 0.2646 - val_acc: 0.8755
# Epoch 34/100
# 4s - loss: 0.1385 - acc: 0.9707 - val_loss: 0.2121 - val_acc: 0.9094
# Epoch 35/100
# 4s - loss: 0.1298 - acc: 0.9688 - val_loss: 0.3033 - val_acc: 0.8906
# Epoch 36/100
# 4s - loss: 0.1368 - acc: 0.9631 - val_loss: 0.4406 - val_acc: 0.8491
# Epoch 37/100
# 4s - loss: 0.1255 - acc: 0.9726 - val_loss: 0.2302 - val_acc: 0.9094
# Epoch 38/100
# 4s - loss: 0.1176 - acc: 0.9745 - val_loss: 0.1990 - val_acc: 0.9321
# Epoch 39/100
# 4s - loss: 0.1335 - acc: 0.9716 - val_loss: 0.4167 - val_acc: 0.8491
# Epoch 40/100
# 4s - loss: 0.1197 - acc: 0.9679 - val_loss: 0.3755 - val_acc: 0.8755
# Epoch 41/100
# 4s - loss: 0.1020 - acc: 0.9802 - val_loss: 0.2610 - val_acc: 0.9170
# Epoch 42/100
# 4s - loss: 0.1053 - acc: 0.9745 - val_loss: 0.2279 - val_acc: 0.8943
# Epoch 43/100
# 4s - loss: 0.0918 - acc: 0.9877 - val_loss: 0.6977 - val_acc: 0.8226
# Epoch 44/100
# 4s - loss: 0.1897 - acc: 0.9452 - val_loss: 0.2698 - val_acc: 0.9170
# Epoch 45/100
# 4s - loss: 0.1471 - acc: 0.9622 - val_loss: 0.2536 - val_acc: 0.9170
# Epoch 46/100
# 4s - loss: 0.1540 - acc: 0.9594 - val_loss: 0.3030 - val_acc: 0.8830
# Epoch 47/100
# 4s - loss: 0.1237 - acc: 0.9716 - val_loss: 0.1909 - val_acc: 0.9132
# Epoch 48/100
# 4s - loss: 0.1083 - acc: 0.9754 - val_loss: 0.2797 - val_acc: 0.9170
# Epoch 49/100
# 4s - loss: 0.1052 - acc: 0.9783 - val_loss: 0.4268 - val_acc: 0.8717
# Epoch 50/100
# 4s - loss: 0.1048 - acc: 0.9783 - val_loss: 0.3411 - val_acc: 0.8906
# Epoch 51/100
# 4s - loss: 0.1566 - acc: 0.9641 - val_loss: 0.2441 - val_acc: 0.9019
# Epoch 52/100
# 4s - loss: 0.1833 - acc: 0.9518 - val_loss: 0.2315 - val_acc: 0.9057
# Epoch 53/100
# 4s - loss: 0.1043 - acc: 0.9792 - val_loss: 0.2807 - val_acc: 0.8830
# Epoch 54/100
# 4s - loss: 0.0892 - acc: 0.9858 - val_loss: 0.3636 - val_acc: 0.8717
# Epoch 55/100
# 4s - loss: 0.0848 - acc: 0.9887 - val_loss: 0.3363 - val_acc: 0.8906
# Epoch 56/100
# 4s - loss: 0.0774 - acc: 0.9924 - val_loss: 0.4388 - val_acc: 0.8717
# Epoch 57/100
# 4s - loss: 0.1009 - acc: 0.9811 - val_loss: 0.2887 - val_acc: 0.8981
# Epoch 58/100
# 4s - loss: 0.0979 - acc: 0.9792 - val_loss: 0.2871 - val_acc: 0.8981
# Epoch 59/100
# 4s - loss: 0.0958 - acc: 0.9830 - val_loss: 0.2436 - val_acc: 0.8981
# Epoch 60/100
# 4s - loss: 0.1081 - acc: 0.9754 - val_loss: 0.3628 - val_acc: 0.8868
# Epoch 61/100
# 4s - loss: 0.0913 - acc: 0.9849 - val_loss: 0.4347 - val_acc: 0.9057
# Epoch 62/100
# 4s - loss: 0.0750 - acc: 0.9896 - val_loss: 0.3697 - val_acc: 0.8792
# Epoch 63/100
# 4s - loss: 0.0764 - acc: 0.9905 - val_loss: 0.3557 - val_acc: 0.8830
# Epoch 64/100
# 4s - loss: 0.0692 - acc: 0.9943 - val_loss: 0.3867 - val_acc: 0.9057
# Epoch 65/100
# 4s - loss: 0.0766 - acc: 0.9849 - val_loss: 0.3166 - val_acc: 0.9019
# Epoch 66/100
# 4s - loss: 0.0918 - acc: 0.9868 - val_loss: 0.2315 - val_acc: 0.9208
# Epoch 67/100
# 4s - loss: 0.0678 - acc: 0.9943 - val_loss: 0.2659 - val_acc: 0.9132
# Epoch 68/100
# 4s - loss: 0.0989 - acc: 0.9830 - val_loss: 0.2892 - val_acc: 0.9283
# Epoch 69/100
# 4s - loss: 0.0696 - acc: 0.9877 - val_loss: 0.3878 - val_acc: 0.8943
# Epoch 70/100
# 4s - loss: 0.0682 - acc: 0.9887 - val_loss: 0.3380 - val_acc: 0.9132
# Epoch 71/100
# 4s - loss: 0.0670 - acc: 0.9915 - val_loss: 0.3360 - val_acc: 0.9170
# Epoch 72/100
# 4s - loss: 0.0876 - acc: 0.9858 - val_loss: 0.3080 - val_acc: 0.9245
# Epoch 73/100
# 4s - loss: 0.1525 - acc: 0.9622 - val_loss: 0.3879 - val_acc: 0.8717
# Epoch 74/100
# 4s - loss: 0.0868 - acc: 0.9896 - val_loss: 0.3218 - val_acc: 0.8981
# Epoch 75/100
# 4s - loss: 0.0681 - acc: 0.9896 - val_loss: 0.2829 - val_acc: 0.9094
# Epoch 76/100
# 4s - loss: 0.0653 - acc: 0.9943 - val_loss: 0.3046 - val_acc: 0.9094
# Epoch 77/100
# 4s - loss: 0.0821 - acc: 0.9858 - val_loss: 0.3048 - val_acc: 0.9208
# Epoch 78/100
# 4s - loss: 0.0720 - acc: 0.9905 - val_loss: 0.3754 - val_acc: 0.9057
# Epoch 79/100
# 4s - loss: 0.0759 - acc: 0.9905 - val_loss: 0.2849 - val_acc: 0.8906
# Epoch 80/100
# 4s - loss: 0.0690 - acc: 0.9915 - val_loss: 0.2996 - val_acc: 0.9019
# Epoch 81/100
# 4s - loss: 0.0736 - acc: 0.9868 - val_loss: 0.2917 - val_acc: 0.8868
# Epoch 82/100
# 4s - loss: 0.4297 - acc: 0.8771 - val_loss: 0.3313 - val_acc: 0.8566
# Epoch 83/100
# 4s - loss: 0.1948 - acc: 0.9480 - val_loss: 0.3970 - val_acc: 0.8491
# Epoch 84/100
# 4s - loss: 0.1593 - acc: 0.9688 - val_loss: 0.2804 - val_acc: 0.9019
# Epoch 85/100
# 4s - loss: 0.1358 - acc: 0.9726 - val_loss: 0.2422 - val_acc: 0.9094
# Epoch 86/100
# 4s - loss: 0.1134 - acc: 0.9764 - val_loss: 0.2202 - val_acc: 0.9283
# Epoch 87/100
# 4s - loss: 0.0940 - acc: 0.9868 - val_loss: 0.2945 - val_acc: 0.9132
# Epoch 88/100
# 4s - loss: 0.0856 - acc: 0.9868 - val_loss: 0.2285 - val_acc: 0.9321
# Epoch 89/100
# 4s - loss: 0.0775 - acc: 0.9896 - val_loss: 0.2539 - val_acc: 0.9283
# Epoch 90/100
# 4s - loss: 0.0977 - acc: 0.9802 - val_loss: 0.4381 - val_acc: 0.8906
# Epoch 91/100
# 4s - loss: 0.1249 - acc: 0.9764 - val_loss: 0.3188 - val_acc: 0.8830
# Epoch 92/100
# 4s - loss: 0.1028 - acc: 0.9830 - val_loss: 0.2683 - val_acc: 0.9132
# Epoch 93/100
# 4s - loss: 0.0768 - acc: 0.9915 - val_loss: 0.2832 - val_acc: 0.9245
# Epoch 94/100
# 4s - loss: 0.0662 - acc: 0.9953 - val_loss: 0.2763 - val_acc: 0.9245
# Epoch 95/100
# 4s - loss: 0.0739 - acc: 0.9915 - val_loss: 0.2406 - val_acc: 0.9358
# Epoch 96/100
# 4s - loss: 0.0836 - acc: 0.9858 - val_loss: 0.4454 - val_acc: 0.8868
# Epoch 97/100
# 4s - loss: 0.1173 - acc: 0.9783 - val_loss: 0.4065 - val_acc: 0.9019
# Epoch 98/100
# 4s - loss: 0.0800 - acc: 0.9915 - val_loss: 0.2717 - val_acc: 0.9208
# Epoch 99/100
# 4s - loss: 0.0736 - acc: 0.9905 - val_loss: 0.3246 - val_acc: 0.9170
# Epoch 100/100
# 4s - loss: 0.0810 - acc: 0.9915 - val_loss: 0.3091 - val_acc: 0.9094
# Train on 1058 samples, validate on 265 samples
# Epoch 1/100
# 6s - loss: 2.7277 - acc: 0.5510 - val_loss: 0.6540 - val_acc: 0.6038
# Epoch 2/100
# 4s - loss: 0.6810 - acc: 0.7108 - val_loss: 0.5050 - val_acc: 0.7623
# Epoch 3/100
# 4s - loss: 0.5911 - acc: 0.7665 - val_loss: 0.4763 - val_acc: 0.8038
# Epoch 4/100
# 4s - loss: 0.5081 - acc: 0.8289 - val_loss: 0.6871 - val_acc: 0.6377
# Epoch 5/100
# 4s - loss: 0.4640 - acc: 0.8535 - val_loss: 0.6006 - val_acc: 0.6415
# Epoch 6/100
# 4s - loss: 0.5368 - acc: 0.8100 - val_loss: 0.3696 - val_acc: 0.8717
# Epoch 7/100
# 4s - loss: 0.3857 - acc: 0.8913 - val_loss: 0.3878 - val_acc: 0.8717
# Epoch 8/100
# 4s - loss: 0.4015 - acc: 0.8696 - val_loss: 0.3330 - val_acc: 0.8906
# Epoch 9/100
# 4s - loss: 0.4130 - acc: 0.8724 - val_loss: 0.4132 - val_acc: 0.8340
# Epoch 10/100
# 4s - loss: 0.3937 - acc: 0.8866 - val_loss: 0.3208 - val_acc: 0.8868
# Epoch 11/100
# 4s - loss: 0.4286 - acc: 0.8658 - val_loss: 0.3549 - val_acc: 0.8566
# Epoch 12/100
# 4s - loss: 0.4292 - acc: 0.8837 - val_loss: 0.3133 - val_acc: 0.8943
# Epoch 13/100
# 4s - loss: 0.3347 - acc: 0.8904 - val_loss: 0.3275 - val_acc: 0.8755
# Epoch 14/100
# 4s - loss: 0.3743 - acc: 0.8913 - val_loss: 0.3194 - val_acc: 0.8755
# Epoch 15/100
# 4s - loss: 0.3147 - acc: 0.8998 - val_loss: 0.3503 - val_acc: 0.8528
# Epoch 16/100
# 4s - loss: 0.3374 - acc: 0.9017 - val_loss: 0.3211 - val_acc: 0.8755
# Epoch 17/100
# 4s - loss: 0.3004 - acc: 0.9064 - val_loss: 0.3066 - val_acc: 0.9019
# Epoch 18/100
# 4s - loss: 0.2849 - acc: 0.9102 - val_loss: 0.2905 - val_acc: 0.8604
# Epoch 19/100
# 4s - loss: 0.2800 - acc: 0.9234 - val_loss: 0.2730 - val_acc: 0.8679
# Epoch 20/100
# 4s - loss: 0.3444 - acc: 0.8847 - val_loss: 0.2623 - val_acc: 0.8868
# Epoch 21/100
# 4s - loss: 0.2554 - acc: 0.9319 - val_loss: 0.3022 - val_acc: 0.8792
# Epoch 22/100
# 4s - loss: 0.2891 - acc: 0.9206 - val_loss: 0.2392 - val_acc: 0.8943
# Epoch 23/100
# 4s - loss: 0.3121 - acc: 0.9102 - val_loss: 0.2762 - val_acc: 0.8755
# Epoch 24/100
# 4s - loss: 0.2518 - acc: 0.9310 - val_loss: 0.2343 - val_acc: 0.8868
# Epoch 25/100
# 4s - loss: 0.2651 - acc: 0.9140 - val_loss: 0.2744 - val_acc: 0.8906
# Epoch 26/100
# 4s - loss: 0.4102 - acc: 0.8989 - val_loss: 0.2770 - val_acc: 0.9208
# Epoch 27/100
# 4s - loss: 0.3314 - acc: 0.9055 - val_loss: 0.2294 - val_acc: 0.8981
# Epoch 28/100
# 4s - loss: 0.2583 - acc: 0.9282 - val_loss: 0.3649 - val_acc: 0.8264
# Epoch 29/100
# 4s - loss: 0.2392 - acc: 0.9386 - val_loss: 0.3049 - val_acc: 0.8792
# Epoch 30/100
# 4s - loss: 0.2182 - acc: 0.9423 - val_loss: 0.2172 - val_acc: 0.9132
# Epoch 31/100
# 4s - loss: 0.4056 - acc: 0.9159 - val_loss: 0.2341 - val_acc: 0.8906
# Epoch 32/100
# 4s - loss: 0.2673 - acc: 0.9395 - val_loss: 0.2054 - val_acc: 0.9094
# Epoch 33/100
# 4s - loss: 0.2215 - acc: 0.9367 - val_loss: 0.3266 - val_acc: 0.8491
# Epoch 34/100
# 4s - loss: 0.2449 - acc: 0.9329 - val_loss: 0.3622 - val_acc: 0.8755
# Epoch 35/100
# 4s - loss: 0.2485 - acc: 0.9253 - val_loss: 0.2103 - val_acc: 0.9019
# Epoch 36/100
# 4s - loss: 0.2138 - acc: 0.9452 - val_loss: 0.2120 - val_acc: 0.8981
# Epoch 37/100
# 4s - loss: 0.2037 - acc: 0.9442 - val_loss: 0.2218 - val_acc: 0.8943
# Epoch 38/100
# 4s - loss: 0.2591 - acc: 0.9225 - val_loss: 0.4811 - val_acc: 0.8000
# Epoch 39/100
# 4s - loss: 0.2465 - acc: 0.9310 - val_loss: 0.1846 - val_acc: 0.9170
# Epoch 40/100
# 4s - loss: 0.2040 - acc: 0.9452 - val_loss: 0.2498 - val_acc: 0.9019
# Epoch 41/100
# 4s - loss: 0.2170 - acc: 0.9527 - val_loss: 0.2153 - val_acc: 0.9170
# Epoch 42/100
# 4s - loss: 0.2157 - acc: 0.9452 - val_loss: 0.1735 - val_acc: 0.9283
# Epoch 43/100
# 4s - loss: 0.1752 - acc: 0.9556 - val_loss: 0.1812 - val_acc: 0.9094
# Epoch 44/100
# 4s - loss: 0.1744 - acc: 0.9546 - val_loss: 0.1891 - val_acc: 0.9170
# Epoch 45/100
# 4s - loss: 0.2397 - acc: 0.9319 - val_loss: 0.1861 - val_acc: 0.9094
# Epoch 46/100
# 4s - loss: 0.2090 - acc: 0.9527 - val_loss: 0.1776 - val_acc: 0.9321
# Epoch 47/100
# 4s - loss: 0.2045 - acc: 0.9480 - val_loss: 0.2703 - val_acc: 0.8679
# Epoch 48/100
# 4s - loss: 0.2106 - acc: 0.9509 - val_loss: 0.1933 - val_acc: 0.9321
# Epoch 49/100
# 4s - loss: 0.1777 - acc: 0.9603 - val_loss: 0.1632 - val_acc: 0.9321
# Epoch 50/100
# 4s - loss: 0.1686 - acc: 0.9603 - val_loss: 0.2048 - val_acc: 0.9094
# Epoch 51/100
# 4s - loss: 0.1893 - acc: 0.9537 - val_loss: 0.2084 - val_acc: 0.9019
# Epoch 52/100
# 4s - loss: 0.1855 - acc: 0.9565 - val_loss: 0.1676 - val_acc: 0.9358
# Epoch 53/100
# 4s - loss: 0.2226 - acc: 0.9423 - val_loss: 0.2340 - val_acc: 0.9094
# Epoch 54/100
# 4s - loss: 0.1863 - acc: 0.9612 - val_loss: 0.1758 - val_acc: 0.9245
# Epoch 55/100
# 4s - loss: 0.1644 - acc: 0.9641 - val_loss: 0.1732 - val_acc: 0.9208
# Epoch 56/100
# 4s - loss: 0.1748 - acc: 0.9612 - val_loss: 0.2529 - val_acc: 0.8943
# Epoch 57/100
# 4s - loss: 0.2103 - acc: 0.9518 - val_loss: 0.1780 - val_acc: 0.9132
# Epoch 58/100
# 4s - loss: 0.1659 - acc: 0.9679 - val_loss: 0.1586 - val_acc: 0.9245
# Epoch 59/100
# 4s - loss: 0.1934 - acc: 0.9480 - val_loss: 0.1952 - val_acc: 0.9208
# Epoch 60/100
# 4s - loss: 0.1909 - acc: 0.9584 - val_loss: 0.1859 - val_acc: 0.9132
# Epoch 61/100
# 4s - loss: 0.1707 - acc: 0.9612 - val_loss: 0.3333 - val_acc: 0.8642
# Epoch 62/100
# 4s - loss: 0.2864 - acc: 0.9272 - val_loss: 0.1741 - val_acc: 0.9283
# Epoch 63/100
# 4s - loss: 0.1828 - acc: 0.9650 - val_loss: 0.1897 - val_acc: 0.9208
# Epoch 64/100
# 4s - loss: 0.1494 - acc: 0.9698 - val_loss: 0.1872 - val_acc: 0.9245
# Epoch 65/100
# 4s - loss: 0.1274 - acc: 0.9726 - val_loss: 0.1842 - val_acc: 0.9208
# Epoch 66/100
# 4s - loss: 0.1605 - acc: 0.9537 - val_loss: 0.2443 - val_acc: 0.9019
# Epoch 67/100
# 4s - loss: 0.2804 - acc: 0.9367 - val_loss: 0.4402 - val_acc: 0.8717
# Epoch 68/100
# 4s - loss: 0.2635 - acc: 0.9442 - val_loss: 0.1825 - val_acc: 0.9170
# Epoch 69/100
# 4s - loss: 0.1777 - acc: 0.9603 - val_loss: 0.1593 - val_acc: 0.9321
# Epoch 70/100
# 4s - loss: 0.1307 - acc: 0.9745 - val_loss: 0.1588 - val_acc: 0.9321
# Epoch 71/100
# 4s - loss: 0.1306 - acc: 0.9764 - val_loss: 0.1478 - val_acc: 0.9321
# Epoch 72/100
# 4s - loss: 0.1456 - acc: 0.9688 - val_loss: 0.2118 - val_acc: 0.9170
# Epoch 73/100
# 4s - loss: 0.1450 - acc: 0.9688 - val_loss: 0.1649 - val_acc: 0.9245
# Epoch 74/100
# 4s - loss: 0.1513 - acc: 0.9603 - val_loss: 0.1246 - val_acc: 0.9434
# Epoch 75/100
# 4s - loss: 0.1516 - acc: 0.9698 - val_loss: 0.1551 - val_acc: 0.9170
# Epoch 76/100
# 4s - loss: 0.1386 - acc: 0.9698 - val_loss: 0.1664 - val_acc: 0.9472
# Epoch 77/100
# 4s - loss: 0.1193 - acc: 0.9802 - val_loss: 0.1564 - val_acc: 0.9208
# Epoch 78/100
# 4s - loss: 0.1536 - acc: 0.9641 - val_loss: 0.1969 - val_acc: 0.9132
# Epoch 79/100
# 4s - loss: 0.1856 - acc: 0.9584 - val_loss: 0.2172 - val_acc: 0.9170
# Epoch 80/100
# 4s - loss: 0.3659 - acc: 0.9319 - val_loss: 0.2261 - val_acc: 0.9245
# Epoch 81/100
# 4s - loss: 0.2260 - acc: 0.9594 - val_loss: 0.1930 - val_acc: 0.9472
# Epoch 82/100
# 4s - loss: 0.1515 - acc: 0.9669 - val_loss: 0.1809 - val_acc: 0.9283
# Epoch 83/100
# 4s - loss: 0.1804 - acc: 0.9480 - val_loss: 0.2096 - val_acc: 0.9358
# Epoch 84/100
# 4s - loss: 0.1594 - acc: 0.9669 - val_loss: 0.2029 - val_acc: 0.9283
# Epoch 85/100
# 4s - loss: 0.1434 - acc: 0.9754 - val_loss: 0.1563 - val_acc: 0.9283
# Epoch 86/100
# 4s - loss: 0.1463 - acc: 0.9707 - val_loss: 0.2581 - val_acc: 0.9019
# Epoch 87/100
# 4s - loss: 0.1571 - acc: 0.9726 - val_loss: 0.1679 - val_acc: 0.9358
# Epoch 88/100
# 4s - loss: 0.1359 - acc: 0.9726 - val_loss: 0.1472 - val_acc: 0.9208
# Epoch 89/100
# 4s - loss: 0.1662 - acc: 0.9688 - val_loss: 0.1307 - val_acc: 0.9358
# Epoch 90/100
# 4s - loss: 0.1418 - acc: 0.9773 - val_loss: 0.2178 - val_acc: 0.9321
# Epoch 91/100
# 4s - loss: 0.1336 - acc: 0.9802 - val_loss: 0.1665 - val_acc: 0.9321
# Epoch 92/100
# 4s - loss: 0.1186 - acc: 0.9754 - val_loss: 0.1438 - val_acc: 0.9283
# Epoch 93/100
# 4s - loss: 0.1642 - acc: 0.9641 - val_loss: 0.2142 - val_acc: 0.9321
# Epoch 94/100
# 4s - loss: 0.1711 - acc: 0.9631 - val_loss: 0.2190 - val_acc: 0.9208
# Epoch 95/100
# 4s - loss: 0.2515 - acc: 0.9490 - val_loss: 0.1784 - val_acc: 0.9245
# Epoch 96/100
# 4s - loss: 0.1938 - acc: 0.9660 - val_loss: 0.1620 - val_acc: 0.9321
# Epoch 97/100
# 4s - loss: 0.1296 - acc: 0.9783 - val_loss: 0.1270 - val_acc: 0.9585
# Epoch 98/100
# 4s - loss: 0.1150 - acc: 0.9773 - val_loss: 0.2056 - val_acc: 0.9321
# Epoch 99/100
# 4s - loss: 0.1039 - acc: 0.9820 - val_loss: 0.1744 - val_acc: 0.9208
# Epoch 100/100
# 4s - loss: 0.1167 - acc: 0.9792 - val_loss: 0.1552 - val_acc: 0.9396
# Train on 1058 samples, validate on 265 samples
# Epoch 1/100
# 6s - loss: 0.9547 - acc: 0.5945 - val_loss: 0.6424 - val_acc: 0.7962
# Epoch 2/100
# 4s - loss: 0.5917 - acc: 0.7703 - val_loss: 0.5105 - val_acc: 0.7472
# Epoch 3/100
# 4s - loss: 0.4839 - acc: 0.8289 - val_loss: 0.4323 - val_acc: 0.8113
# Epoch 4/100
# 4s - loss: 0.4293 - acc: 0.8516 - val_loss: 0.3739 - val_acc: 0.8642
# Epoch 5/100
# 4s - loss: 0.4594 - acc: 0.8422 - val_loss: 0.4946 - val_acc: 0.7774
# Epoch 6/100
# 4s - loss: 0.4068 - acc: 0.8592 - val_loss: 0.4051 - val_acc: 0.8340
# Epoch 7/100
# 4s - loss: 0.3790 - acc: 0.8781 - val_loss: 0.4766 - val_acc: 0.7547
# Epoch 8/100
# 4s - loss: 0.3572 - acc: 0.8800 - val_loss: 0.3588 - val_acc: 0.9019
# Epoch 9/100
# 4s - loss: 0.3122 - acc: 0.8960 - val_loss: 0.3771 - val_acc: 0.8302
# Epoch 10/100
# 4s - loss: 0.2973 - acc: 0.9083 - val_loss: 0.3722 - val_acc: 0.8943
# Epoch 11/100
# 4s - loss: 0.3645 - acc: 0.8781 - val_loss: 0.3630 - val_acc: 0.8868
# Epoch 12/100
# 4s - loss: 0.3042 - acc: 0.9017 - val_loss: 0.3287 - val_acc: 0.9057
# Epoch 13/100
# 4s - loss: 0.2469 - acc: 0.9225 - val_loss: 0.3930 - val_acc: 0.8528
# Epoch 14/100
# 4s - loss: 0.2556 - acc: 0.9263 - val_loss: 0.3065 - val_acc: 0.8868
# Epoch 15/100
# 4s - loss: 0.2681 - acc: 0.9225 - val_loss: 0.3574 - val_acc: 0.8792
# Epoch 16/100
# 4s - loss: 0.2817 - acc: 0.9045 - val_loss: 0.2969 - val_acc: 0.8943
# Epoch 17/100
# 4s - loss: 0.2319 - acc: 0.9310 - val_loss: 0.3720 - val_acc: 0.9019
# Epoch 18/100
# 4s - loss: 0.2769 - acc: 0.9159 - val_loss: 0.4072 - val_acc: 0.8528
# Epoch 19/100
# 4s - loss: 0.4195 - acc: 0.8639 - val_loss: 0.3411 - val_acc: 0.8792
# Epoch 20/100
# 4s - loss: 0.2462 - acc: 0.9386 - val_loss: 0.2853 - val_acc: 0.8792
# Epoch 21/100
# 4s - loss: 0.2679 - acc: 0.9225 - val_loss: 0.3197 - val_acc: 0.8943
# Epoch 22/100
# 4s - loss: 0.2122 - acc: 0.9442 - val_loss: 0.3254 - val_acc: 0.8604
# Epoch 23/100
# 4s - loss: 0.2795 - acc: 0.9112 - val_loss: 0.4907 - val_acc: 0.8000
# Epoch 24/100
# 4s - loss: 0.2645 - acc: 0.9197 - val_loss: 0.3750 - val_acc: 0.9057
# Epoch 25/100
# 4s - loss: 0.2150 - acc: 0.9405 - val_loss: 0.3830 - val_acc: 0.8981
# Epoch 26/100
# 4s - loss: 0.1924 - acc: 0.9480 - val_loss: 0.3052 - val_acc: 0.9132
# Epoch 27/100
# 4s - loss: 0.1924 - acc: 0.9461 - val_loss: 0.2713 - val_acc: 0.9019
# Epoch 28/100
# 4s - loss: 0.2080 - acc: 0.9452 - val_loss: 0.3746 - val_acc: 0.8604
# Epoch 29/100
# 4s - loss: 0.1899 - acc: 0.9575 - val_loss: 0.2771 - val_acc: 0.9094
# Epoch 30/100
# 4s - loss: 0.1830 - acc: 0.9537 - val_loss: 0.2733 - val_acc: 0.9094
# Epoch 31/100
# 4s - loss: 0.2570 - acc: 0.9291 - val_loss: 0.3669 - val_acc: 0.8868
# Epoch 32/100
# 4s - loss: 0.2592 - acc: 0.9244 - val_loss: 0.4843 - val_acc: 0.8642
# Epoch 33/100
# 4s - loss: 0.1944 - acc: 0.9575 - val_loss: 0.3579 - val_acc: 0.8943
# Epoch 34/100
# 4s - loss: 0.1985 - acc: 0.9518 - val_loss: 0.4864 - val_acc: 0.8377
# Epoch 35/100
# 4s - loss: 0.2221 - acc: 0.9423 - val_loss: 0.2891 - val_acc: 0.9094
# Epoch 36/100
# 4s - loss: 0.2068 - acc: 0.9565 - val_loss: 0.2776 - val_acc: 0.9019
# Epoch 37/100
# 4s - loss: 0.2189 - acc: 0.9490 - val_loss: 0.2093 - val_acc: 0.9019
# Epoch 38/100
# 4s - loss: 0.1915 - acc: 0.9584 - val_loss: 0.2962 - val_acc: 0.8868
# Epoch 39/100
# 4s - loss: 0.1746 - acc: 0.9556 - val_loss: 0.3565 - val_acc: 0.9019
# Epoch 40/100
# 4s - loss: 0.1908 - acc: 0.9556 - val_loss: 0.3313 - val_acc: 0.9019
# Epoch 41/100
# 4s - loss: 0.1744 - acc: 0.9641 - val_loss: 0.2631 - val_acc: 0.9132
# Epoch 42/100
# 4s - loss: 0.1589 - acc: 0.9688 - val_loss: 0.3128 - val_acc: 0.8981
# Epoch 43/100
# 4s - loss: 0.1417 - acc: 0.9679 - val_loss: 0.3955 - val_acc: 0.8868
# Epoch 44/100
# 4s - loss: 0.1483 - acc: 0.9716 - val_loss: 0.3316 - val_acc: 0.8943
# Epoch 45/100
# 4s - loss: 0.1371 - acc: 0.9726 - val_loss: 0.3228 - val_acc: 0.9019
# Epoch 46/100
# 4s - loss: 0.1939 - acc: 0.9575 - val_loss: 0.3786 - val_acc: 0.9094
# Epoch 47/100
# 4s - loss: 0.1943 - acc: 0.9603 - val_loss: 0.3910 - val_acc: 0.8906
# Epoch 48/100
# 4s - loss: 0.2042 - acc: 0.9509 - val_loss: 0.3677 - val_acc: 0.8906
# Epoch 49/100
# 4s - loss: 0.2567 - acc: 0.9405 - val_loss: 0.2887 - val_acc: 0.8906
# Epoch 50/100
# 4s - loss: 0.1795 - acc: 0.9660 - val_loss: 0.2530 - val_acc: 0.9208
# Epoch 51/100
# 4s - loss: 0.1552 - acc: 0.9726 - val_loss: 0.3693 - val_acc: 0.9208
# Epoch 52/100
# 4s - loss: 0.1675 - acc: 0.9612 - val_loss: 0.2859 - val_acc: 0.8868
# Epoch 53/100
# 4s - loss: 0.1485 - acc: 0.9698 - val_loss: 0.3261 - val_acc: 0.9019
# Epoch 54/100
# 4s - loss: 0.1363 - acc: 0.9764 - val_loss: 0.3309 - val_acc: 0.8943
# Epoch 55/100
# 4s - loss: 0.1997 - acc: 0.9509 - val_loss: 0.3234 - val_acc: 0.8830
# Epoch 56/100
# 4s - loss: 0.1700 - acc: 0.9679 - val_loss: 0.2916 - val_acc: 0.9094
# Epoch 57/100
# 4s - loss: 0.1850 - acc: 0.9631 - val_loss: 0.3001 - val_acc: 0.9019
# Epoch 58/100
# 4s - loss: 0.1985 - acc: 0.9537 - val_loss: 0.3030 - val_acc: 0.9094
# Epoch 59/100
# 4s - loss: 0.1547 - acc: 0.9754 - val_loss: 0.3137 - val_acc: 0.9208
# Epoch 60/100
# 4s - loss: 0.1612 - acc: 0.9716 - val_loss: 0.3677 - val_acc: 0.8792
# Epoch 61/100
# 4s - loss: 0.1337 - acc: 0.9802 - val_loss: 0.3480 - val_acc: 0.8943
# Epoch 62/100
# 4s - loss: 0.1305 - acc: 0.9830 - val_loss: 0.4075 - val_acc: 0.9057
# Epoch 63/100
# 4s - loss: 0.1528 - acc: 0.9745 - val_loss: 0.2900 - val_acc: 0.8755
# Epoch 64/100
# 4s - loss: 0.2049 - acc: 0.9594 - val_loss: 0.2684 - val_acc: 0.8906
# Epoch 65/100
# 4s - loss: 0.1681 - acc: 0.9716 - val_loss: 0.3115 - val_acc: 0.9057
# Epoch 66/100
# 4s - loss: 0.1458 - acc: 0.9773 - val_loss: 0.3583 - val_acc: 0.9057
# Epoch 67/100
# 4s - loss: 0.1547 - acc: 0.9688 - val_loss: 0.3212 - val_acc: 0.8717
# Epoch 68/100
# 4s - loss: 0.1996 - acc: 0.9641 - val_loss: 0.3820 - val_acc: 0.9132
# Epoch 69/100
# 4s - loss: 0.1987 - acc: 0.9603 - val_loss: 0.3180 - val_acc: 0.8981
# Epoch 70/100
# 4s - loss: 0.2088 - acc: 0.9622 - val_loss: 0.2789 - val_acc: 0.8755
# Epoch 71/100
# 4s - loss: 0.1785 - acc: 0.9660 - val_loss: 0.2969 - val_acc: 0.9094
# Epoch 72/100
# 4s - loss: 0.1910 - acc: 0.9594 - val_loss: 0.2635 - val_acc: 0.9245
# Epoch 73/100
# 4s - loss: 0.1683 - acc: 0.9650 - val_loss: 0.3838 - val_acc: 0.9019
# Epoch 74/100
# 4s - loss: 0.1281 - acc: 0.9830 - val_loss: 0.3951 - val_acc: 0.9321
# Epoch 75/100
# 4s - loss: 0.1249 - acc: 0.9764 - val_loss: 0.4811 - val_acc: 0.8528
# Epoch 76/100
# 4s - loss: 0.1472 - acc: 0.9698 - val_loss: 0.3701 - val_acc: 0.8981
# Epoch 77/100
# 4s - loss: 0.1833 - acc: 0.9698 - val_loss: 0.5732 - val_acc: 0.8528
# Epoch 78/100
# 4s - loss: 0.1587 - acc: 0.9754 - val_loss: 0.3197 - val_acc: 0.8906
# Epoch 79/100
# 4s - loss: 0.1304 - acc: 0.9820 - val_loss: 0.3163 - val_acc: 0.9094
# Epoch 80/100
# 4s - loss: 0.1397 - acc: 0.9792 - val_loss: 0.3759 - val_acc: 0.8981
# Epoch 81/100
# 4s - loss: 0.1245 - acc: 0.9830 - val_loss: 0.4520 - val_acc: 0.8906
# Epoch 82/100
# 4s - loss: 0.1564 - acc: 0.9679 - val_loss: 0.4169 - val_acc: 0.9019
# Epoch 83/100
# 4s - loss: 0.2141 - acc: 0.9584 - val_loss: 0.3791 - val_acc: 0.8755
# Epoch 84/100
# 4s - loss: 0.2017 - acc: 0.9584 - val_loss: 0.4148 - val_acc: 0.8943
# Epoch 85/100
# 4s - loss: 0.1613 - acc: 0.9698 - val_loss: 0.3877 - val_acc: 0.9094
# Epoch 86/100
# 4s - loss: 0.1524 - acc: 0.9688 - val_loss: 0.2450 - val_acc: 0.9057
# Epoch 87/100
# 4s - loss: 0.1474 - acc: 0.9764 - val_loss: 0.3614 - val_acc: 0.9208
# Epoch 88/100
# 4s - loss: 0.1526 - acc: 0.9688 - val_loss: 0.3717 - val_acc: 0.9057
# Epoch 89/100
# 4s - loss: 0.1322 - acc: 0.9792 - val_loss: 0.3793 - val_acc: 0.9019
# Epoch 90/100
# 4s - loss: 0.1160 - acc: 0.9858 - val_loss: 0.4339 - val_acc: 0.8792
# Epoch 91/100
# 4s - loss: 0.1426 - acc: 0.9726 - val_loss: 0.3804 - val_acc: 0.9132
# Epoch 92/100
# 4s - loss: 0.1242 - acc: 0.9849 - val_loss: 0.4862 - val_acc: 0.8830
# Epoch 93/100
# 4s - loss: 0.1814 - acc: 0.9650 - val_loss: 0.4484 - val_acc: 0.8943
# Epoch 94/100
# 4s - loss: 0.1559 - acc: 0.9726 - val_loss: 0.4295 - val_acc: 0.8679
# Epoch 95/100
# 4s - loss: 0.3625 - acc: 0.9055 - val_loss: 0.3188 - val_acc: 0.8792
# Epoch 96/100
# 4s - loss: 0.2251 - acc: 0.9612 - val_loss: 0.2666 - val_acc: 0.8679
# Epoch 97/100
# 4s - loss: 0.1866 - acc: 0.9735 - val_loss: 0.3683 - val_acc: 0.8981
# Epoch 98/100
# 4s - loss: 0.1788 - acc: 0.9773 - val_loss: 0.2532 - val_acc: 0.9208
# Epoch 99/100
# 4s - loss: 0.1663 - acc: 0.9745 - val_loss: 0.3832 - val_acc: 0.8981
# Epoch 100/100
# 4s - loss: 0.1366 - acc: 0.9839 - val_loss: 0.3902 - val_acc: 0.9170
# Train on 1058 samples, validate on 265 samples
# Epoch 1/100
# 6s - loss: 0.7021 - acc: 0.5208 - val_loss: 0.6598 - val_acc: 0.5698
# Epoch 2/100
# 4s - loss: 0.6045 - acc: 0.6900 - val_loss: 0.5446 - val_acc: 0.7321
# Epoch 3/100
# 4s - loss: 0.5136 - acc: 0.7524 - val_loss: 0.5268 - val_acc: 0.7509
# Epoch 4/100
# 4s - loss: 0.4157 - acc: 0.8251 - val_loss: 0.4300 - val_acc: 0.8075
# Epoch 5/100
# 4s - loss: 0.3345 - acc: 0.8715 - val_loss: 0.3626 - val_acc: 0.8415
# Epoch 6/100
# 4s - loss: 0.3015 - acc: 0.8875 - val_loss: 0.3129 - val_acc: 0.8642
# Epoch 7/100
# 4s - loss: 0.2719 - acc: 0.9008 - val_loss: 0.3337 - val_acc: 0.8717
# Epoch 8/100
# 4s - loss: 0.2330 - acc: 0.9149 - val_loss: 0.2906 - val_acc: 0.8717
# Epoch 9/100
# 4s - loss: 0.2611 - acc: 0.9036 - val_loss: 0.2599 - val_acc: 0.8906
# Epoch 10/100
# 4s - loss: 0.2492 - acc: 0.9064 - val_loss: 0.2508 - val_acc: 0.9170
# Epoch 11/100
# 4s - loss: 0.2139 - acc: 0.9159 - val_loss: 0.3239 - val_acc: 0.8566
# Epoch 12/100
# 4s - loss: 0.1878 - acc: 0.9159 - val_loss: 0.2928 - val_acc: 0.8868
# Epoch 13/100
# 4s - loss: 0.1748 - acc: 0.9291 - val_loss: 0.2716 - val_acc: 0.8717
# Epoch 14/100
# 4s - loss: 0.1394 - acc: 0.9490 - val_loss: 0.2910 - val_acc: 0.8830
# Epoch 15/100
# 4s - loss: 0.1350 - acc: 0.9499 - val_loss: 0.2188 - val_acc: 0.8943
# Epoch 16/100
# 4s - loss: 0.1543 - acc: 0.9405 - val_loss: 0.2224 - val_acc: 0.8943
# Epoch 17/100
# 4s - loss: 0.1358 - acc: 0.9480 - val_loss: 0.2891 - val_acc: 0.9019
# Epoch 18/100
# 4s - loss: 0.1495 - acc: 0.9461 - val_loss: 0.3334 - val_acc: 0.8792
# Epoch 19/100
# 4s - loss: 0.1383 - acc: 0.9499 - val_loss: 0.2203 - val_acc: 0.8981
# Epoch 20/100
# 4s - loss: 0.1102 - acc: 0.9556 - val_loss: 0.2503 - val_acc: 0.8981
# Epoch 21/100
# 4s - loss: 0.1099 - acc: 0.9594 - val_loss: 0.2507 - val_acc: 0.8906
# Epoch 22/100
# 4s - loss: 0.1330 - acc: 0.9509 - val_loss: 0.2449 - val_acc: 0.8906
# Epoch 23/100
# 4s - loss: 0.0893 - acc: 0.9716 - val_loss: 0.2354 - val_acc: 0.9057
# Epoch 24/100
# 4s - loss: 0.2081 - acc: 0.9253 - val_loss: 0.4026 - val_acc: 0.8717
# Epoch 25/100
# 4s - loss: 0.2109 - acc: 0.9216 - val_loss: 0.2584 - val_acc: 0.9132
# Epoch 26/100
# 4s - loss: 0.0884 - acc: 0.9735 - val_loss: 0.2356 - val_acc: 0.9094
# Epoch 27/100
# 4s - loss: 0.0827 - acc: 0.9698 - val_loss: 0.2216 - val_acc: 0.8981
# Epoch 28/100
# 4s - loss: 0.0877 - acc: 0.9698 - val_loss: 0.3030 - val_acc: 0.8755
# Epoch 29/100
# 4s - loss: 0.0963 - acc: 0.9650 - val_loss: 0.3167 - val_acc: 0.9170
# Epoch 30/100
# 4s - loss: 0.1065 - acc: 0.9631 - val_loss: 0.2576 - val_acc: 0.9094
# Epoch 31/100
# 4s - loss: 0.0748 - acc: 0.9802 - val_loss: 0.2436 - val_acc: 0.8981
# Epoch 32/100
# 4s - loss: 0.0673 - acc: 0.9764 - val_loss: 0.2635 - val_acc: 0.9094
# Epoch 33/100
# 4s - loss: 0.0625 - acc: 0.9802 - val_loss: 0.2552 - val_acc: 0.9208
# Epoch 34/100
# 4s - loss: 0.0742 - acc: 0.9754 - val_loss: 0.3046 - val_acc: 0.9170
# Epoch 35/100
# 4s - loss: 0.0704 - acc: 0.9802 - val_loss: 0.2746 - val_acc: 0.9019
# Epoch 36/100
# 4s - loss: 0.0596 - acc: 0.9830 - val_loss: 0.2952 - val_acc: 0.9283
# Epoch 37/100
# 4s - loss: 0.0654 - acc: 0.9811 - val_loss: 0.3087 - val_acc: 0.9019
# Epoch 38/100
# 4s - loss: 0.1194 - acc: 0.9631 - val_loss: 0.4178 - val_acc: 0.8717
# Epoch 39/100
# 4s - loss: 0.1415 - acc: 0.9518 - val_loss: 0.3138 - val_acc: 0.8830
# Epoch 40/100
# 4s - loss: 0.1251 - acc: 0.9631 - val_loss: 0.2771 - val_acc: 0.9057
# Epoch 41/100
# 4s - loss: 0.0621 - acc: 0.9858 - val_loss: 0.2551 - val_acc: 0.9132
# Epoch 42/100
# 4s - loss: 0.0505 - acc: 0.9849 - val_loss: 0.3062 - val_acc: 0.9094
# Epoch 43/100
# 4s - loss: 0.0596 - acc: 0.9839 - val_loss: 0.2364 - val_acc: 0.9094
# Epoch 44/100
# 4s - loss: 0.0497 - acc: 0.9849 - val_loss: 0.3793 - val_acc: 0.8906
# Epoch 45/100
# 4s - loss: 0.0403 - acc: 0.9924 - val_loss: 0.2873 - val_acc: 0.9132
# Epoch 46/100
# 4s - loss: 0.0478 - acc: 0.9839 - val_loss: 0.2917 - val_acc: 0.9208
# Epoch 47/100
# 4s - loss: 0.0447 - acc: 0.9887 - val_loss: 0.3274 - val_acc: 0.9132
# Epoch 48/100
# 4s - loss: 0.0412 - acc: 0.9915 - val_loss: 0.4202 - val_acc: 0.8906
# Epoch 49/100
# 4s - loss: 0.0392 - acc: 0.9896 - val_loss: 0.3762 - val_acc: 0.8906
# Epoch 50/100
# 4s - loss: 0.0296 - acc: 0.9953 - val_loss: 0.3129 - val_acc: 0.9170
# Epoch 51/100
# 4s - loss: 0.0311 - acc: 0.9962 - val_loss: 0.3152 - val_acc: 0.9094
# Epoch 52/100
# 4s - loss: 0.0992 - acc: 0.9754 - val_loss: 0.4089 - val_acc: 0.8642
# Epoch 53/100
# 4s - loss: 0.0567 - acc: 0.9877 - val_loss: 0.2579 - val_acc: 0.9057
# Epoch 54/100
# 4s - loss: 0.1315 - acc: 0.9509 - val_loss: 0.6271 - val_acc: 0.8453
# Epoch 55/100
# 4s - loss: 0.1137 - acc: 0.9612 - val_loss: 0.4654 - val_acc: 0.8604
# Epoch 56/100
# 4s - loss: 0.0665 - acc: 0.9849 - val_loss: 0.2995 - val_acc: 0.9057
# Epoch 57/100
# 4s - loss: 0.0912 - acc: 0.9745 - val_loss: 0.2926 - val_acc: 0.9057
# Epoch 58/100
# 4s - loss: 0.0404 - acc: 0.9924 - val_loss: 0.3665 - val_acc: 0.8981
# Epoch 59/100
# 4s - loss: 0.0463 - acc: 0.9915 - val_loss: 0.3316 - val_acc: 0.9132
# Epoch 60/100
# 4s - loss: 0.0411 - acc: 0.9934 - val_loss: 0.3165 - val_acc: 0.9057
# Epoch 61/100
# 4s - loss: 0.0388 - acc: 0.9915 - val_loss: 0.3236 - val_acc: 0.9170
# Epoch 62/100
# 4s - loss: 0.0373 - acc: 0.9934 - val_loss: 0.2997 - val_acc: 0.9245
# Epoch 63/100
# 4s - loss: 0.0316 - acc: 0.9953 - val_loss: 0.3650 - val_acc: 0.9057
# Epoch 64/100
# 4s - loss: 0.0278 - acc: 0.9962 - val_loss: 0.3753 - val_acc: 0.9208
# Epoch 65/100
# 4s - loss: 0.0342 - acc: 0.9962 - val_loss: 0.3148 - val_acc: 0.8981
# Epoch 66/100
# 4s - loss: 0.0320 - acc: 0.9943 - val_loss: 0.2860 - val_acc: 0.9283
# Epoch 67/100
# 4s - loss: 0.0292 - acc: 0.9962 - val_loss: 0.3243 - val_acc: 0.9132
# Epoch 68/100
# 4s - loss: 0.0372 - acc: 0.9915 - val_loss: 0.5276 - val_acc: 0.8906
# Epoch 69/100
# 4s - loss: 0.0613 - acc: 0.9830 - val_loss: 0.4378 - val_acc: 0.8981
# Epoch 70/100
# 4s - loss: 0.0637 - acc: 0.9830 - val_loss: 0.3423 - val_acc: 0.9019
# Epoch 71/100
# 4s - loss: 0.0640 - acc: 0.9849 - val_loss: 0.4189 - val_acc: 0.9170
# Epoch 72/100
# 4s - loss: 0.1346 - acc: 0.9641 - val_loss: 0.3639 - val_acc: 0.8868
# Epoch 73/100
# 4s - loss: 0.0448 - acc: 0.9915 - val_loss: 0.2620 - val_acc: 0.9132
# Epoch 74/100
# 4s - loss: 0.0369 - acc: 0.9962 - val_loss: 0.3265 - val_acc: 0.9170
# Epoch 75/100
# 4s - loss: 0.0411 - acc: 0.9934 - val_loss: 0.3816 - val_acc: 0.9132
# Epoch 76/100
# 4s - loss: 0.0409 - acc: 0.9915 - val_loss: 0.3001 - val_acc: 0.9170
# Epoch 77/100
# 4s - loss: 0.0351 - acc: 0.9953 - val_loss: 0.3551 - val_acc: 0.9245
# Epoch 78/100
# 4s - loss: 0.0427 - acc: 0.9905 - val_loss: 0.2839 - val_acc: 0.9132
# Epoch 79/100
# 4s - loss: 0.0546 - acc: 0.9868 - val_loss: 0.3087 - val_acc: 0.8981
# Epoch 80/100
# 4s - loss: 0.0456 - acc: 0.9896 - val_loss: 0.3618 - val_acc: 0.9094
# Epoch 81/100
# 4s - loss: 0.0448 - acc: 0.9915 - val_loss: 0.3892 - val_acc: 0.8830
# Epoch 82/100
# 4s - loss: 0.0443 - acc: 0.9934 - val_loss: 0.3905 - val_acc: 0.9283
# Epoch 83/100
# 4s - loss: 0.0338 - acc: 0.9943 - val_loss: 0.3643 - val_acc: 0.9094
# Epoch 84/100
# 4s - loss: 0.0305 - acc: 0.9981 - val_loss: 0.5690 - val_acc: 0.8755
# Epoch 85/100
# 4s - loss: 0.0841 - acc: 0.9726 - val_loss: 0.3910 - val_acc: 0.9283
# Epoch 86/100
# 4s - loss: 0.0693 - acc: 0.9811 - val_loss: 1.1109 - val_acc: 0.8075
# Epoch 87/100
# 4s - loss: 0.0561 - acc: 0.9839 - val_loss: 0.4048 - val_acc: 0.9057
# Epoch 88/100
# 4s - loss: 0.1488 - acc: 0.9622 - val_loss: 0.4345 - val_acc: 0.8981
# Epoch 89/100
# 4s - loss: 0.0697 - acc: 0.9858 - val_loss: 0.3972 - val_acc: 0.8981
# Epoch 90/100
# 4s - loss: 0.0497 - acc: 0.9915 - val_loss: 0.2749 - val_acc: 0.9170
# Epoch 91/100
# 4s - loss: 0.0450 - acc: 0.9905 - val_loss: 0.2875 - val_acc: 0.9057
# Epoch 92/100
# 4s - loss: 0.0324 - acc: 0.9981 - val_loss: 0.2906 - val_acc: 0.9208
# Epoch 93/100
# 4s - loss: 0.0429 - acc: 0.9934 - val_loss: 0.3282 - val_acc: 0.9245
# Epoch 94/100
# 4s - loss: 0.0279 - acc: 1.0000 - val_loss: 0.3830 - val_acc: 0.9208
# Epoch 95/100
# 4s - loss: 0.0392 - acc: 0.9943 - val_loss: 0.2590 - val_acc: 0.9208
# Epoch 96/100
# 4s - loss: 0.0333 - acc: 0.9962 - val_loss: 0.3560 - val_acc: 0.9170
# Epoch 97/100
# 4s - loss: 0.0379 - acc: 0.9934 - val_loss: 0.3397 - val_acc: 0.9170
# Epoch 98/100
# 4s - loss: 0.0385 - acc: 0.9924 - val_loss: 0.4105 - val_acc: 0.8981
# Epoch 99/100
# 4s - loss: 0.0297 - acc: 0.9972 - val_loss: 0.4000 - val_acc: 0.9208
# Epoch 100/100
# 4s - loss: 0.0283 - acc: 0.9972 - val_loss: 0.3011 - val_acc: 0.9132

# %%
show_results(results_dropout, window_size=5)
# Out:
# convolving with window_size  5
# convolving with window_size  5
# convolving with window_size  5
# convolving with window_size  5
# convolving with window_size  5
# convolving with window_size  5
# convolving with window_size  5
# convolving with window_size  5

# %%
print(sklearn.metrics.classification_report(np.argmax(data.train_dev.y, axis=1), np.argmax(model.predict(data.train_dev.X), axis=1)))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.97      0.93      0.95        84
#           1       0.91      0.97      0.94        64
#
# avg / total       0.95      0.95      0.95       148

# %%
model = keras.models.load_model('model.h5')

# %%
pp = model.predict_proba(data.test.X)
# Out:
# 490/490 [==============================] - 20s

# %%
fpr, tpr, thresholds = sklearn.metrics.roc_curve(data.test.y[:,0], pp[:,0])
auc = sklearn.metrics.auc(fpr, tpr)

# %%
fig, axs = plt.subplots(1,2, figsize=(20,10))

plt.figure()
lw = 2
axs[0].plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (AUC={:.5f})'.format(auc))
axs[0].plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
axs[0].set_xlim([0.0, 1.0])
axs[0].set_ylim([0.0, 1.01])
axs[0].set_xlabel('False Positive Rate')
axs[0].set_ylabel('True Positive Rate')
axs[0].set_title('Receiver operating characteristic example')
axs[0].legend(loc="lower right")

axs[1].plot(thresholds, tpr, color='darkblue', label='TPR for threshold')
axs[1].set_xlabel('Threshold')
axs[1].set_ylabel('TPR')


plt.show()

# %%
rs = data.test.X[np.argmax(data.test.y, axis=1) != np.argmax(pp, axis=1)][:50]
rs_pred = pp[np.argmax(data.test.y, axis=1) != np.argmax(pp, axis=1)][:50]
rs.shape
# Out:
# (27, 3, 100, 100)

# %%
print("rs measn  - ", np.mean(rs, axis=(0,2,3)))
print("rgb_means - ", rgb_means)
# Out:
# rs measn  -  [ 0.55837057  0.51539211  0.49636774]
# rgb_means -  [ 0.5387489   0.49949211  0.46680889]

# %%
fig, axs = plt.subplots(rs.shape[0]//5 + 1, 5, figsize=(15,15))
axs = axs.flatten()

for idx, z in enumerate(zip(rs, rs_pred)):
    r,r_pred = z
    axs[idx].imshow(r.transpose(1,2,0))
    axs[idx].text(0, 0, "[{:.2f},{:.2f}]".format(*r_pred), color='red', size=15 )

# %%
model.layers
# Out:
# [<keras.layers.convolutional.Convolution2D at 0x12298df98>,
#  <keras.layers.convolutional.Convolution2D at 0x1229b59e8>,
#  <keras.layers.pooling.MaxPooling2D at 0x122a78278>,
#  <keras.layers.core.Dropout at 0x122a70b38>,
#  <keras.layers.convolutional.Convolution2D at 0x122aa4cf8>,
#  <keras.layers.convolutional.Convolution2D at 0x122ace2e8>,
#  <keras.layers.pooling.MaxPooling2D at 0x122ac8860>,
#  <keras.layers.core.Dropout at 0x122afdba8>,
#  <keras.layers.core.Flatten at 0x122b3f4a8>,
#  <keras.layers.core.Dense at 0x122b49e80>,
#  <keras.layers.core.Dense at 0x122b3fdd8>]

# %%
filters = model.layers[1].get_weights()[0]

fig, axs = plt.subplots(filters.shape[0]//5 + 1, 5, figsize=(15,15))
axs = axs.flatten()

for idx, f in enumerate(filters):
    axs[idx].imshow(f.transpose(0), interpolation='nearest')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-184-49bf512527e5> in <module>()
#       5
#       6 for idx, f in enumerate(filters):
# ----> 7     axs[idx].imshow(f.transpose(0), interpolation='nearest')
#
# ValueError: axes don't match array

# %%
import pickle

pickle.dump({ 'results_1_layer': results, 'results_2_layers': results_2_layers}, open("results.pickle", "wb"))

# %%
for n,h in results_2_layers:
    del h.model
